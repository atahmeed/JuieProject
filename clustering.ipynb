# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
srilankan_dataset = pd.read_excel('Dataset/SG-INDIAN-MALES-SG-INDIAN-FEMALES.xlsx')

# %%
srilankan_dataset = srilankan_dataset.drop(['Nationality','Ethinicity'],axis=1)
srilankan_dataset.head()
# Out:
#    PIN  Age     HL     HW     FL     FW    NL    NW         CI         NI  \
# 0   53   24  18.10  14.25  11.35  14.25  4.57  2.80  78.729282  61.269147
# 1   60   20  18.30  14.00  10.05  14.80  3.70  2.50  76.502732  67.567568
# 2   81   21  18.25  14.75  11.65  13.55  5.30  3.25  80.821918  61.320755
# 3   82   20  17.90  14.70  12.35  13.80  5.30  3.15  82.122905  59.433962
# 4   85   22  17.75  13.35  11.25  14.00  3.85  2.60  75.211268  67.532468
#
#           FI  Sex
# 0  79.649123    0
# 1  67.905405    0
# 2  85.977860    0
# 3  89.492754    0
# 4  80.357143    0

# %%
Sdataset = np.array(srilankan_dataset)


X_male = Sdataset[Sdataset[:,11]==0]
X_female = Sdataset[Sdataset[:,11]==1]

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_male
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_male[:,8],X_male[:,9],X_male[:,10],color='r')
ax.scatter(X_female[:,8],X_female[:,9],X_female[:,10],color='b')

# X = srilankan_dataset.drop(['Sex'],axis=1)
# X = scaler.fit_transform(X)
# Y = srilankan_dataset['Sex']
# X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3, random_state=42)

# %%
kmeans = KMeans(n_clusters=2, random_state=42)

# %%
kmeans.fit(X_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
print(kmeans.predict(X_test))
# Out:
# [0 1 1 1 1 1 1 1 0 1 1 1]

# %%
from sklearn.metrics import confusion_matrix
